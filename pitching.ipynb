# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("Pitching.csv")
aw = pd.read_csv("AwardsPlayers.csv")

# %%
df.shape
# Out:
# (44139, 30)

# %%
df.columns
# Out:
# Index(['playerID', 'yearID', 'stint', 'teamID', 'lgID', 'W', 'L', 'G', 'GS',
#        'CG', 'SHO', 'SV', 'IPouts', 'H', 'ER', 'HR', 'BB', 'SO', 'BAOpp',
#        'ERA', 'IBB', 'WP', 'HBP', 'BK', 'BFP', 'GF', 'R', 'SH', 'SF', 'GIDP'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# playerID        0
# yearID          0
# stint           0
# teamID          0
# lgID          131
# W               0
# L               0
# G               0
# GS              0
# CG              0
# SHO             0
# SV              0
# IPouts          1
# H               0
# ER              0
# HR              0
# BB              0
# SO              0
# BAOpp        1525
# ERA            90
# IBB         14575
# WP            133
# HBP           559
# BK              0
# BFP           239
# GF            133
# R               0
# SH          32900
# SF          32900
# GIDP        43394
# dtype: int64

# %%
df.head()
# Out:
#     playerID  yearID  stint teamID lgID   W   L   G  GS  CG  ...  IBB  WP  \
# 0  bechtge01    1871      1    PH1  NaN   1   2   3   3   2  ...  NaN NaN
# 1  brainas01    1871      1    WS3  NaN  12  15  30  30  30  ...  NaN NaN
# 2  fergubo01    1871      1    NY2  NaN   0   0   1   0   0  ...  NaN NaN
# 3  fishech01    1871      1    RC1  NaN   4  16  24  24  22  ...  NaN NaN
# 4  fleetfr01    1871      1    NY2  NaN   0   1   1   1   1  ...  NaN NaN
#
#    HBP  BK  BFP  GF    R  SH  SF  GIDP
# 0  NaN   0  NaN NaN   42 NaN NaN   NaN
# 1  NaN   0  NaN NaN  292 NaN NaN   NaN
# 2  NaN   0  NaN NaN    9 NaN NaN   NaN
# 3  NaN   0  NaN NaN  257 NaN NaN   NaN
# 4  NaN   0  NaN NaN   21 NaN NaN   NaN
#
# [5 rows x 30 columns]

# %%
df=df[df["yearID"] >= 2000]
df.head()
# Out:
#         playerID  yearID  stint teamID lgID  W  L   G  GS  CG  ...  IBB   WP  \
# 32900  abbotpa01    2000      1    SEA   AL  9  7  35  27   0  ...  4.0  3.0
# 32901  aceveju01    2000      1    MIL   NL  3  7  62   0   0  ...  9.0  3.0
# 32902  adamste01    2000      1    LAN   NL  6  9  66   0   0  ...  0.0  5.0
# 32903  aguilri01    2000      1    CHN   NL  1  2  54   0   0  ...  2.0  1.0
# 32904  aldresc01    2000      1    PHI   NL  1  3  23   0   0  ...  0.0  1.0
#
#        HBP  BK    BFP    GF   R   SH   SF  GIDP
# 32900  5.0   0  766.0   2.0  89  1.0  4.0   NaN
# 32901  1.0   2  347.0  18.0  38  1.0  1.0   NaN
# 32902  0.0   0  369.0  18.0  42  3.0  0.0   NaN
# 32903  4.0   0  210.0  44.0  28  1.0  0.0   NaN
# 32904  1.0   0   95.0   5.0  14  1.0  2.0   NaN
#
# [5 rows x 30 columns]

# %%
aw=aw[aw["yearID"] >= 2000]
aw=aw[aw["awardID"] == "Cy Young Award"]

# %%
aw.head()
# Out:
#        playerID         awardID  yearID lgID  tie notes
# 4961  martipe02  Cy Young Award    2000   AL  NaN   NaN
# 4962  johnsra05  Cy Young Award    2000   NL  NaN   NaN
# 5042  clemero02  Cy Young Award    2001   AL  NaN   NaN
# 5043  johnsra05  Cy Young Award    2001   NL  NaN   NaN
# 5124   zitoba01  Cy Young Award    2002   AL  NaN   NaN

# %%
aw.shape
# Out:
# (32, 6)

# %%
aw["awardID"] = 1

# %%
bb=df.merge(aw[["playerID", "yearID", "awardID"]], on=["playerID", "yearID"], how="left")

# %%
bb["awardID"]=bb["awardID"].fillna(0).astype(int)

# %%
bb.head()
# Out:
#     playerID  yearID  stint teamID lgID  W  L   G  GS  CG  ...   WP  HBP  BK  \
# 0  abbotpa01    2000      1    SEA   AL  9  7  35  27   0  ...  3.0  5.0   0
# 1  aceveju01    2000      1    MIL   NL  3  7  62   0   0  ...  3.0  1.0   2
# 2  adamste01    2000      1    LAN   NL  6  9  66   0   0  ...  5.0  0.0   0
# 3  aguilri01    2000      1    CHN   NL  1  2  54   0   0  ...  1.0  4.0   0
# 4  aldresc01    2000      1    PHI   NL  1  3  23   0   0  ...  1.0  1.0   0
#
#      BFP    GF   R   SH   SF  GIDP  awardID
# 0  766.0   2.0  89  1.0  4.0   NaN        0
# 1  347.0  18.0  38  1.0  1.0   NaN        0
# 2  369.0  18.0  42  3.0  0.0   NaN        0
# 3  210.0  44.0  28  1.0  0.0   NaN        0
# 4   95.0   5.0  14  1.0  2.0   NaN        0
#
# [5 rows x 31 columns]

# %%
bb.columns
# Out:
# Index(['playerID', 'yearID', 'stint', 'teamID', 'lgID', 'W', 'L', 'G', 'GS',
#        'CG', 'SHO', 'SV', 'IPouts', 'H', 'ER', 'HR', 'BB', 'SO', 'BAOpp',
#        'ERA', 'IBB', 'WP', 'HBP', 'BK', 'BFP', 'GF', 'R', 'SH', 'SF', 'GIDP',
#        'awardID'],
#       dtype='object')

# %%
bb[bb["awardID"] == 1]
# Out:
#         playerID  yearID  stint teamID lgID   W   L   G  GS  CG  ...    WP  \
# 263    johnsra05    2000      1    ARI   NL  19   7  35  35   8  ...   5.0
# 330    martipe02    2000      1    BOS   AL  18   6  29  29   7  ...   1.0
# 774    clemero02    2001      1    NYA   AL  20   3  33  33   0  ...  14.0
# 937    johnsra05    2001      1    ARI   NL  21   6  35  34   3  ...   8.0
# 1597   johnsra05    2002      1    ARI   NL  24   5  35  35   8  ...   3.0
# 1987    zitoba01    2002      1    OAK   AL  23   5  35  35   1  ...   2.0
# 2186   gagneer01    2003      1    LAN   NL   2   3  77   0   0  ...   2.0
# 2219   hallaro01    2003      1    TOR   AL  22   7  36  36   9  ...   6.0
# 2776   clemero02    2004      1    HOU   NL  18   4  33  33   0  ...   5.0
# 3204   santajo01    2004      1    MIN   AL  20   6  34  34   1  ...   7.0
# 3438   carpech01    2005      1    SLN   NL  21   5  33  33   7  ...   5.0
# 3462   colonba01    2005      1    LAA   AL  21   8  33  33   2  ...   2.0
# 4538   santajo01    2006      1    MIN   AL  19   6  34  34   1  ...   4.0
# 4653    webbbr01    2006      1    ARI   NL  16   8  33  33   5  ...   5.0
# 5178   peavyja01    2007      1    SDN   NL  19   6  34  34   0  ...   4.0
# 5248   sabatcc01    2007      1    CLE   AL  19   7  34  34   4  ...   1.0
# 5752     leecl02    2008      1    CLE   AL  22   3  31  31   4  ...   4.0
# 5759   linceti01    2008      1    SFN   NL  18   5  34  33   2  ...  17.0
# 6355   greinza01    2009      1    KCA   AL  16   8  33  33   6  ...   5.0
# 6466   linceti01    2009      1    SFN   NL  15   7  32  32   4  ...  11.0
# 7071   hallaro01    2010      1    PHI   NL  21  10  33  33   9  ...   5.0
# 7093   hernafe02    2010      1    SEA   AL  13  12  34  34   6  ...  14.0
# 7852   kershcl01    2011      1    LAN   NL  21   5  33  33   5  ...   5.0
# 8184   verlaju01    2011      1    DET   AL  24   5  34  34   4  ...   7.0
# 8414   dickera01    2012      1    NYN   NL  20   6  34  33   5  ...   4.0
# 8764   priceda01    2012      1    TBA   AL  20   5  31  31   2  ...   8.0
# 9303   kershcl01    2013      1    LAN   NL  16   9  33  33   3  ...  12.0
# 9566   scherma01    2013      1    DET   AL  21   3  32  32   0  ...   6.0
# 10035  kershcl01    2014      1    LAN   NL  21   3  27  27   6  ...   7.0
# 10042  klubeco01    2014      1    CLE   AL  18   9  34  34   3  ...   3.0
# 10455  arrieja01    2015      1    CHN   NL  22   6  33  33   4  ...   6.0
# 10824  keuchda01    2015      1    HOU   AL  20   8  33  33   3  ...   9.0
#
#         HBP  BK     BFP    GF    R    SH   SF  GIDP  awardID
# 263     6.0   2  1001.0   0.0   89  14.0  5.0   NaN        1
# 330    14.0   0   817.0   0.0   44   2.0  1.0   NaN        1
# 774     5.0   0   918.0   0.0   94   4.0  4.0   NaN        1
# 937    18.0   1   994.0   1.0   74  10.0  5.0   NaN        1
# 1597   13.0   2  1035.0   0.0   78   4.0  2.0   NaN        1
# 1987    9.0   1   939.0   0.0   79   9.0  7.0   NaN        1
# 2186    3.0   0   306.0  67.0   12   4.0  0.0   NaN        1
# 2219    9.0   1  1071.0   0.0  111   3.0  2.0   NaN        1
# 2776    6.0   0   878.0   0.0   76   8.0  7.0   NaN        1
# 3204    9.0   0   881.0   0.0   70   3.0  3.0   NaN        1
# 3438    3.0   0   953.0   0.0   82   7.0  7.0   NaN        1
# 3462    3.0   1   906.0   0.0   93   9.0  4.0   NaN        1
# 4538    4.0   1   923.0   0.0   79   6.0  4.0   NaN        1
# 4653    6.0   2   950.0   0.0   91  10.0  6.0   NaN        1
# 5178    6.0   0   898.0   0.0   67   5.0  7.0   NaN        1
# 5248    8.0   0   975.0   0.0   94   6.0  6.0   NaN        1
# 5752    5.0   0   891.0   0.0   68   2.0  3.0   NaN        1
# 5759    6.0   2   928.0   0.0   72  11.0  3.0   NaN        1
# 6355    4.0   0   915.0   0.0   64   8.0  3.0   NaN        1
# 6466    6.0   0   905.0   0.0   69  12.0  5.0   NaN        1
# 7071    6.0   1   993.0   0.0   74   9.0  5.0   NaN        1
# 7093    8.0   1  1001.0   0.0   80   6.0  3.0   NaN        1
# 7852    3.0   1   912.0   0.0   66  11.0  2.0   NaN        1
# 8184    3.0   2   969.0   0.0   73   2.0  3.0   NaN        1
# 8414    9.0   1   927.0   1.0   78   9.0  7.0   NaN        1
# 8764    5.0   1   836.0   0.0   63   2.0  3.0   NaN        1
# 9303    3.0   2   908.0   0.0   55   8.0  3.0   NaN        1
# 9566    4.0   1   836.0   0.0   73   2.0  8.0   NaN        1
# 10035   2.0   2   749.0   0.0   42   6.0  1.0  15.0        1
# 10042   6.0   0   951.0   0.0   72   5.0  2.0  16.0        1
# 10455   6.0   0   870.0   0.0   52   4.0  1.0   NaN        1
# 10824   2.0   0   911.0   0.0   68   1.0  3.0   NaN        1
#
# [32 rows x 31 columns]

# %%
bb.isnull().sum()
# Out:
# playerID        0
# yearID          0
# stint           0
# teamID          0
# lgID            0
# W               0
# L               0
# G               0
# GS              0
# CG              0
# SHO             0
# SV              0
# IPouts          1
# H               0
# ER              0
# HR              0
# BB              0
# SO              0
# BAOpp           6
# ERA            14
# IBB             0
# WP              0
# HBP             1
# BK              0
# BFP             0
# GF              0
# R               0
# SH              0
# SF              0
# GIDP        10494
# awardID         0
# dtype: int64

# %%
bb=bb.dropna(subset="ERA")

# %%
bb["HBP"]=bb["HBP"].fillna(0)
bb["GIDP"]=bb["GIDP"].fillna(0)
bb["IPouts"]=bb["IPouts"].fillna(0)
bb["BAOpp"]=bb["BAOpp"].fillna(0)

# %%
bb.isnull().sum()
# Out:
# playerID    0
# yearID      0
# stint       0
# teamID      0
# lgID        0
# W           0
# L           0
# G           0
# GS          0
# CG          0
# SHO         0
# SV          0
# IPouts      0
# H           0
# ER          0
# HR          0
# BB          0
# SO          0
# BAOpp       0
# ERA         0
# IBB         0
# WP          0
# HBP         0
# BK          0
# BFP         0
# GF          0
# R           0
# SH          0
# SF          0
# GIDP        0
# awardID     0
# dtype: int64

# %%
bb.dtypes
# Out:
# playerID     object
# yearID        int64
# stint         int64
# teamID       object
# lgID         object
# W             int64
# L             int64
# G             int64
# GS            int64
# CG            int64
# SHO           int64
# SV            int64
# IPouts      float64
# H             int64
# ER            int64
# HR            int64
# BB            int64
# SO            int64
# BAOpp       float64
# ERA         float64
# IBB         float64
# WP          float64
# HBP         float64
# BK            int64
# BFP         float64
# GF          float64
# R             int64
# SH          float64
# SF          float64
# GIDP        float64
# awardID       int64
# dtype: object

# %%
features = ["W", "ERA", "SO", "BB", "CG", "SHO", "ER", "IPouts"]
X=bb[features]
y=bb["awardID"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=24,stratify=y)

# %%
model=RandomForestClassifier(n_estimators=10,class_weight="balanced", random_state=24)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=10,
#                        random_state=24)

# %%
y_predict=model.predict(X_test)
print("Accuracy = ", accuracy_score(y_test, y_predict))
print(classification_report(y_test, y_predict))
# Out:
# Accuracy =  0.9977728285077951
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2239
#            1       0.67      0.33      0.44         6
#
#     accuracy                           1.00      2245
#    macro avg       0.83      0.67      0.72      2245
# weighted avg       1.00      1.00      1.00      2245

# %%
print(confusion_matrix(y_test, y_predict))
# Out:
# [[2238    1]
#  [   4    2]]
